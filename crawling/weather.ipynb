# %%
import requests
# https://www.data.go.kr/data/15084084/openapi.do
# 일반 인증키(Decoding)
service_key = "+gSJiYQdX8owt/K7o6rZZoA91LR/JpfqT9Ihv8wX78Ud2tpcmZ5Ea2pMATbF3KyvXQASZiTIkdC577OPA9rO3g=="
 
url = "http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getUltraSrtNcst"
 
params = {
    "serviceKey": service_key,
    "pageNo": "1",
    "numOfRows": "1000",
    "dataType": "JSON",
    "base_date": "20260327",  # 오늘 날짜
    "base_time": "1200",      # 발표 시간
    "nx": "60",               # x좌표 (서울 기준)
    "ny": "127"               # y좌표
}
 
res = requests.get(url, params=params)
data = res.text # 문자열
 
print(data)
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"baseDate":"20260327","baseTime":"1200","category":"PTY","nx":60,"ny":127,"obsrValue":"0"},{"baseDate":"20260327","baseTime":"1200","category":"REH","nx":60,"ny":127,"obsrValue":"54"},{"baseDate":"20260327","baseTime":"1200","category":"RN1","nx":60,"ny":127,"obsrValue":"0"},{"baseDate":"20260327","baseTime":"1200","category":"T1H","nx":60,"ny":127,"obsrValue":"16.1"},{"baseDate":"20260327","baseTime":"1200","category":"UUU","nx":60,"ny":127,"obsrValue":"1.9"},{"baseDate":"20260327","baseTime":"1200","category":"VEC","nx":60,"ny":127,"obsrValue":"218"},{"baseDate":"20260327","baseTime":"1200","category":"VVV","nx":60,"ny":127,"obsrValue":"2.4"},{"baseDate":"20260327","baseTime":"1200","category":"WSD","nx":60,"ny":127,"obsrValue":"3"}]},"pageNo":1,"numOfRows":1000,"totalCount":8}}}

# %%
data = res.json() # json데이터 딕셔너리 변환
data = data["response"]["body"]["items"]["item"]
 
weather = {}
 
for item in data:
    #카테고리 이름을 key값, 그리고 value값을 지정해준다
    weather[item["category"]] = item["obsrValue"]
 
print(f"""
날짜: {data[0]['baseDate']}
시간: {data[0]['baseTime']}
 
기온: {weather['T1H']}℃
습도: {weather['REH']}%
강수량: {weather['RN1']} mm
강수형태: {"없음" if weather['PTY'] == "0" else weather['PTY']}
 
풍속: {weather['WSD']} m/s
풍향: {weather['VEC']}°
""")
# Out:
# 날짜: 20260327
# 시간: 1200
#
# 기온: 16.1℃
# 습도: 54%
# 강수량: 0 mm
# 강수형태: 없음
#
# 풍속: 3 m/s
# 풍향: 218°
