# %%
import urllib.request
import datetime
import json
import pandas as pd

# https://www.khug.or.kr/priceDistributedPrice3dot3.do
ServiceKey = '82add9a9-ede0-4452-b753-98e360582aea'

def getPrice():
    print('get price')

def main():
    jsonResult = []
    result = []
    print('지역별 ㎡당 분양가격(지역)')
    area_cd = input('지역코드 입력 (01 ~ 16): ')
    start_ym = input('시작 연월 입력 (yyyymm): ')
    #jsonResult, result, area_cd, start_ym = getPrice(area_cd)
    

if __name__ == "__main__":
    main()
